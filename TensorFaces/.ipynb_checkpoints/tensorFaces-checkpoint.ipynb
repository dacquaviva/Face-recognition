# %%
# !pip install tensorly

# %%
import tensorly 
import numpy as np
from PIL import Image
import matplotlib.pylab as plt
from numpy import linalg as la

# %%
np.reshape(plt.imread(("../Data-set/s1/1.pgm")), (10304,1))
# Out:
# array([[48],
#        [49],
#        [45],
#        ...,
#        [47],
#        [46],
#        [46]], dtype=uint8)

# %%
matrix_immagini = np.zeros((10304,7,40)) #array con tutte le immagini (7 trainig, 3 test)
for i in range(40):
    for j in range(7):
        matrix_immagini[:,j,i] = np.reshape(plt.imread(("../Data-set/"+"s"+str(i+1)+'/'+str(j+1)+'.pgm')), (10304))

# %%
immagine = matrix_immagini[:,0,0]

# %%
immagine.shape
# Out:
# (10304,)

# %%
plt.imshow(np.reshape(immagine,(112,92)), cmap='gray')

# %%
X = tensorly.tensor(matrix_immagini)

# %%
type(X)
# Out:
# numpy.ndarray

# %%
type(matrix_immagini)
# Out:
# numpy.ndarray

# %%
U1, s1, V1 = np.linalg.svd(tensorly.unfold(matrix_immagini,0),full_matrices =False)
U2, s2, V2 = np.linalg.svd(tensorly.unfold(matrix_immagini,1),full_matrices=False)
U3, s3, V3 = np.linalg.svd(tensorly.unfold(matrix_immagini,2),full_matrices=False)

# %%
U1.shape
# Out:
# (10304, 280)

# %%
num_eigenpixel = 5

# %%
eigenpixel = np.zeros((10304,num_eigenpixel))
for i in range (num_eigenpixel):
    eigenpixel[:,i] = U1[:,i]

# %%
fig = plt.figure(figsize=(15,15))
for i in range (num_eigenfaces):
    plt.subplot(1,5,i+1)
    plt.imshow(np.reshape(eigenpixel[:,i],(112,92)), cmap='gray')

# %%
tensorly.unfold(matrix_immagini, mode=0).shape
# Out:
# (10304, 280)

# %%
U2.shape
# Out:
# (7, 7)

# %%
tensorly.unfold(matrix_immagini, mode=0).dot(U1.T).shape
# Out:
# (10304, 10304)

# %%
tensorly.tenalg.mode_dot(matrix_immagini, np.transpose(U1), mode=0).shape
# Out:
# (280, 7, 40)

# %%
S=tensorly.tenalg.mode_dot(matrix_immagini, np.transpose(eigenpixel), mode=0)
S=tensorly.tenalg.mode_dot(S, np.transpose(U2), mode=1)
#S=tensorly.tenalg.mode_dot(S, np.transpose(U3), mode=2)

# %%
S.shape
# Out:
# (5, 7, 40)

# %%
bases = np.zeros((280,1,40))

# %%
U1, s1, V1 = np.linalg.svd(S[:,:,i],full_matrices=False)

# %%
U1[:,0].T.shape
# Out:
# (5,)

# %%
k = 1
bases = np.zeros((num_eigenpixel,k,40))
for i in range (40):
    U1, s1, V1 = np.linalg.svd(S[:,:,i],full_matrices=False)
    for j in range(k):
        bases[:,:,i] = np.reshape(eigenpixel[k], ((num_eigenpixel,1)))

# %%
eigenpixel.shape
# Out:
# (10304, 5)

# %%
immagine_test = np.reshape(plt.imread(("../Data-set/s1/8.pgm")), (1,10304))

# %%
immagine_test_tens = immagine_test.dot(eigenpixel)

# %%
bases.shape
# Out:
# (5, 1, 40)

# %%
residui = np.zeros((40))
for i in range(40):
    residui[i] = np.linalg.norm(bases[:,:,i] - immagine_test_tens, 2)
