# %%
# !pip install tensorly
# Out:
# Requirement already satisfied: tensorly in /home/daniele/anaconda3/lib/python3.6/site-packages (0.4.2)
# Requirement already satisfied: nose in /home/daniele/anaconda3/lib/python3.6/site-packages (from tensorly) (1.3.7)
# Requirement already satisfied: scipy in /home/daniele/anaconda3/lib/python3.6/site-packages (from tensorly) (1.1.0)
# Requirement already satisfied: numpy in /home/daniele/anaconda3/lib/python3.6/site-packages (from tensorly) (1.15.2)

# %%
import tensorly 
import numpy as np
from PIL import Image
import matplotlib.pylab as plt
from numpy import linalg as la

# %%
tensor_immagini_traning = np.zeros((10304,7,40)) #array con tutte le immagini (7 trainig, 3 test)
for i in range(40):
    for j in range(7):
        tensor_immagini_traning[:,j,i] = np.reshape(plt.imread(("../Data-set/"+"s"+str(i+1)+'/'+str(j+1)+'.pgm')), (10304))

# %%
plt.imshow(np.reshape(tensor_immagini_traning[:,0,0],(112,92)), cmap='gray')

# %%
U1, s1, V1 = np.linalg.svd(tensorly.unfold(tensor_immagini_traning,0),full_matrices =False)
U2, s2, V2 = np.linalg.svd(tensorly.unfold(tensor_immagini_traning,1),full_matrices=False)
U3, s3, V3 = np.linalg.svd(tensorly.unfold(tensor_immagini_traning,2),full_matrices=False)

# %%
fig1 = plt.figure(figsize=(6,4))
sing_vals = np.arange(280) + 1
plt.plot(sing_vals, s1, 'ro-', linewidth=2)
plt.title('Plot delle variaze')
plt.xlabel('Principal Component')
plt.ylabel('Singular values')
# Out:
# Text(0,0.5,'Singular values')

# %%
fig1 = plt.figure(figsize=(6,4))
sing_vals = np.arange(7) + 1
plt.plot(sing_vals, s2, 'ro-', linewidth=2)
plt.title('Plot delle variaze')
plt.xlabel('Principal Component')
plt.ylabel('Singular values')
# Out:
# Text(0,0.5,'Singular values')

# %%
num_eigenpixel = 2

# %%
num_eigenperson = 2 #(massimo 7)

# %%
eigenpixel = np.zeros((10304,num_eigenpixel))
for i in range (num_eigenpixel):
    eigenpixel[:,i] = U1[:,i]

# %%
eigenperson = np.zeros((7,num_eigenperson))
for i in range (num_eigenperson):
    eigenperson[:,i] = U2[:,i]

# %%
fig = plt.figure(figsize=(15,15))
for i in range (num_eigenpixel):
    plt.subplot(11,5,i+1)
    plt.imshow(np.reshape(eigenpixel[:,i],(112,92)), cmap='gray')

# %%
S=tensorly.tenalg.mode_dot(tensor_immagini_traning, np.transpose(eigenpixel), mode=0)
S=tensorly.tenalg.mode_dot(S, np.transpose(eigenperson), mode=1)
#S=tensorly.tenalg.mode_dot(S, np.transpose(U3), mode=2)

# %%
immagine_test = np.reshape(plt.imread(("../Data-set/s1/10.pgm")), (1,10304))

# %%
immagine_test_tens = immagine_test.dot(eigenpixel)

# %%
core_basis = np.zeros((40))
for i in range (40):
    U1, s1, V1 = np.linalg.svd(S[:,:,i],full_matrices =False)
    core_basis[i] =  np.linalg.norm(U1[:,0] - immagine_test_tens, 2)

# %%
core_basis.argmin()
# Out:
# 0

# %%
core_basis = np.zeros((num_eigenpixel,40))#calcoliamo basi una per ognuna delle 40 persone(prendiamo solo il primo vettore singolare sinistro della svd sulle slice frontali dove ogni slice rappresenta una persona)
for i in range (40):
    U1, s1, V1 = np.linalg.svd(S[:,:,i],full_matrices =False)
    core_basis[:,i] =  U1[:,0]

# %%
tensor_immagini_test = np.zeros((10304,3,40)) #tensore con 3 immagini di test per ogni persona(40 persone)
for i in range(40):
    for j in range(3):
        tensor_immagini_test[:,j,i] = np.reshape(plt.imread(("../Data-set/"+"s"+str(i+1)+'/'+str(j+8)+'.pgm')), (10304))

# %%
tensor_immagini_testj=tensorly.tenalg.mode_dot(tensor_immagini_test, np.transpose(eigenpixel), mode=0)#proietto d*Uj

# %%
residui_minimi = np.zeros((40,3))
residui = np.zeros(40)
for i in range(40):#persone
    for j in range(3):#immagini stessa persona classificate una alla volta
        for k in range(40):
            residui[k] =  np.linalg.norm(core_basis[:,k] -tensor_immagini_testj[:,j,i] , 2)
        residui_minimi[i,j] = residui.argmin()

# %%
residui_minimi
# Out:
# array([[26.,  0.,  0.],
#        [15., 15., 15.],
#        [23., 23., 39.],
#        [ 2., 23., 35.],
#        [39., 38.,  2.],
#        [29., 37.,  5.],
#        [20.,  6., 16.],
#        [23.,  3., 16.],
#        [20., 37.,  8.],
#        [ 9., 29.,  8.],
#        [30., 11., 16.],
#        [ 4., 39.,  2.],
#        [15.,  1., 15.],
#        [36., 12., 18.],
#        [14., 14., 23.],
#        [11., 11., 23.],
#        [19., 28., 28.],
#        [21., 30.,  2.],
#        [18.,  0., 27.],
#        [ 9., 29., 29.],
#        [28.,  8., 20.],
#        [17.,  0., 26.],
#        [29., 22., 19.],
#        [ 6., 35., 16.],
#        [11., 17., 38.],
#        [ 4., 34.,  4.],
#        [10.,  0., 12.],
#        [27., 12., 36.],
#        [22.,  8.,  6.],
#        [19.,  9., 37.],
#        [ 6., 32., 15.],
#        [15.,  1.,  0.],
#        [19., 37., 20.],
#        [15.,  0.,  0.],
#        [38., 31.,  2.],
#        [ 6., 35., 14.],
#        [36., 27., 27.],
#        [29., 20.,  5.],
#        [ 6., 35., 23.],
#        [ 2.,  2.,  2.]])

# %%
num_classificazioni_corrette = 0
k = 0
for i in range(40):
    for j in range(3):
        if(residui_minimi[i,j]==k):
            num_classificazioni_corrette = num_classificazioni_corrette + 1
    k =k + 1

# %%
(num_classificazioni_corrette/120)*100
# Out:
# 11.666666666666666

# %%
def hosvd_classificazione(eigenpixel,i,eigenperson,tensor_immagini_traning,tensor_immagini_test):
    S=tensorly.tenalg.mode_dot(tensor_immagini_traning, np.transpose(eigenpixel), mode=0)
    S=tensorly.tenalg.mode_dot(S, np.transpose(eigenperson), mode=1)
    #S=tensorly.tenalg.mode_dot(S, np.transpose(U3), mode=2)
    core_basis = np.zeros((i,40))#calcoliamo basi una per ognuna delle 40 persone(prendiamo solo il primo vettore singolare sinistro della svd sulle slice frontali dove ogni slice rappresenta una persona)
    for i in range (40):
        U1, s1, V1 = np.linalg.svd(S[:,:,i],full_matrices =False)
        core_basis[:,i] =  U1[:,0]
    tensor_immagini_testj=tensorly.tenalg.mode_dot(tensor_immagini_test, np.transpose(eigenpixel), mode=0)#proietto d*Uj
    residui_minimi = np.zeros((40,3))
    residui = np.zeros(40)
    for i in range(40):#persone
        for j in range(3):#immagini stessa persona classificate una alla volta
            for k in range(40):
                residui[k] =  np.linalg.norm(core_basis[:,k] -tensor_immagini_testj[:,j,i] , 2)
            residui_minimi[i,j] = residui.argmin()
    num_classificazioni_corrette = 0
    k = 0
    for i in range(40):
        for j in range(3):
            if(residui_minimi[i,j]==k):
                num_classificazioni_corrette = num_classificazioni_corrette + 1
        k =k + 1
    return (num_classificazioni_corrette/120)*100

# %%
tensor_immagini_traning = np.zeros((10304,7,40)) #array con tutte le immagini (7 trainig, 3 test)
for i in range(40):
    for j in range(7):
        tensor_immagini_traning[:,j,i] = np.reshape(plt.imread(("../Data-set/"+"s"+str(i+1)+'/'+str(j+1)+'.pgm')), (10304))

# %%
U1, s1, V1 = np.linalg.svd(tensorly.unfold(tensor_immagini_traning,0),full_matrices =False)
U2, s2, V2 = np.linalg.svd(tensorly.unfold(tensor_immagini_traning,1),full_matrices=False)
U3, s3, V3 = np.linalg.svd(tensorly.unfold(tensor_immagini_traning,2),full_matrices=False)

# %%
num_eigenperson = 2 #(massimo 7)
eigenperson = np.zeros((7,num_eigenperson))
for i in range (num_eigenperson):
    eigenperson[:,i] = U2[:,i]

# %%
tensor_immagini_test = np.zeros((10304,3,40)) #tensore con 3 immagini di test per ogni persona(40 persone)
for i in range(40):
    for j in range(3):
        tensor_immagini_test[:,j,i] = np.reshape(plt.imread(("../Data-set/"+"s"+str(i+1)+'/'+str(j+8)+'.pgm')), (10304))

# %%
percentuale_classificazione = np.zeros((280))
for i in range(1,281):
    eigenpixel = np.zeros((10304,i))
    for j in range (i):
        eigenpixel[:,j] = U1[:,j]
    print("Eigenpixel= "+ str(i)+ "       percentuale classificazione= " + str(hosvd_classificazione(eigenpixel,i,eigenperson,tensor_immagini_traning,tensor_immagini_test)))
# Out:
# Eigenpixel= 1       percentuale classificazione= 2.5
# Eigenpixel= 2       percentuale classificazione= 11.666666666666666
# Eigenpixel= 3       percentuale classificazione= 17.5
# Eigenpixel= 4       percentuale classificazione= 32.5
# Eigenpixel= 5       percentuale classificazione= 45.83333333333333
# Eigenpixel= 6       percentuale classificazione= 50.83333333333333
# Eigenpixel= 7       percentuale classificazione= 60.0
# Eigenpixel= 8       percentuale classificazione= 63.33333333333333
# Eigenpixel= 9       percentuale classificazione= 66.66666666666666
# Eigenpixel= 10       percentuale classificazione= 70.83333333333334
# Eigenpixel= 11       percentuale classificazione= 73.33333333333333
# Eigenpixel= 12       percentuale classificazione= 73.33333333333333
# Eigenpixel= 13       percentuale classificazione= 75.83333333333333
# Eigenpixel= 14       percentuale classificazione= 79.16666666666666
# Eigenpixel= 15       percentuale classificazione= 78.33333333333333
# Eigenpixel= 16       percentuale classificazione= 79.16666666666666
# Eigenpixel= 17       percentuale classificazione= 80.83333333333333
# Eigenpixel= 18       percentuale classificazione= 80.83333333333333
# Eigenpixel= 19       percentuale classificazione= 80.83333333333333
# Eigenpixel= 20       percentuale classificazione= 82.5
# Eigenpixel= 21       percentuale classificazione= 83.33333333333334
# Eigenpixel= 22       percentuale classificazione= 84.16666666666667
# Eigenpixel= 23       percentuale classificazione= 83.33333333333334
# Eigenpixel= 24       percentuale classificazione= 84.16666666666667
# Eigenpixel= 25       percentuale classificazione= 83.33333333333334
# Eigenpixel= 26       percentuale classificazione= 84.16666666666667
# Eigenpixel= 27       percentuale classificazione= 85.0
# Eigenpixel= 28       percentuale classificazione= 85.0
# Eigenpixel= 29       percentuale classificazione= 85.0
# Eigenpixel= 30       percentuale classificazione= 85.0
# Eigenpixel= 31       percentuale classificazione= 85.0
# Eigenpixel= 32       percentuale classificazione= 84.16666666666667
# Eigenpixel= 33       percentuale classificazione= 84.16666666666667
# Eigenpixel= 34       percentuale classificazione= 85.0
# Eigenpixel= 35       percentuale classificazione= 85.83333333333333
# Eigenpixel= 36       percentuale classificazione= 85.83333333333333
# Eigenpixel= 37       percentuale classificazione= 86.66666666666667
# Eigenpixel= 38       percentuale classificazione= 85.83333333333333
# Eigenpixel= 39       percentuale classificazione= 85.0
# Eigenpixel= 40       percentuale classificazione= 85.0
# Eigenpixel= 41       percentuale classificazione= 85.0
# Eigenpixel= 42       percentuale classificazione= 85.0
# Eigenpixel= 43       percentuale classificazione= 85.83333333333333
# Eigenpixel= 44       percentuale classificazione= 85.0
# Eigenpixel= 45       percentuale classificazione= 85.0
# Eigenpixel= 46       percentuale classificazione= 85.0
# Eigenpixel= 47       percentuale classificazione= 85.0
# Eigenpixel= 48       percentuale classificazione= 85.0
# Eigenpixel= 49       percentuale classificazione= 85.83333333333333
# Eigenpixel= 50       percentuale classificazione= 86.66666666666667
# Eigenpixel= 51       percentuale classificazione= 85.83333333333333
# Eigenpixel= 52       percentuale classificazione= 86.66666666666667
# Eigenpixel= 53       percentuale classificazione= 87.5
# Eigenpixel= 54       percentuale classificazione= 87.5
# Eigenpixel= 55       percentuale classificazione= 87.5
# Eigenpixel= 56       percentuale classificazione= 86.66666666666667
# Eigenpixel= 57       percentuale classificazione= 87.5
# Eigenpixel= 58       percentuale classificazione= 86.66666666666667
# Eigenpixel= 59       percentuale classificazione= 86.66666666666667
# Eigenpixel= 60       percentuale classificazione= 86.66666666666667
# Eigenpixel= 61       percentuale classificazione= 86.66666666666667
# Eigenpixel= 62       percentuale classificazione= 86.66666666666667
# Eigenpixel= 63       percentuale classificazione= 86.66666666666667
# Eigenpixel= 64       percentuale classificazione= 86.66666666666667
# Eigenpixel= 65       percentuale classificazione= 85.83333333333333
# Eigenpixel= 66       percentuale classificazione= 86.66666666666667
# Eigenpixel= 67       percentuale classificazione= 86.66666666666667
# Eigenpixel= 68       percentuale classificazione= 86.66666666666667
# Eigenpixel= 69       percentuale classificazione= 86.66666666666667
# Eigenpixel= 70       percentuale classificazione= 86.66666666666667
# Eigenpixel= 71       percentuale classificazione= 86.66666666666667
# Eigenpixel= 72       percentuale classificazione= 86.66666666666667
# Eigenpixel= 73       percentuale classificazione= 86.66666666666667
# Eigenpixel= 74       percentuale classificazione= 86.66666666666667
# Eigenpixel= 75       percentuale classificazione= 86.66666666666667
# Eigenpixel= 76       percentuale classificazione= 86.66666666666667
# Eigenpixel= 77       percentuale classificazione= 86.66666666666667
# Eigenpixel= 78       percentuale classificazione= 86.66666666666667
# Eigenpixel= 79       percentuale classificazione= 86.66666666666667
# Eigenpixel= 80       percentuale classificazione= 86.66666666666667
# Eigenpixel= 81       percentuale classificazione= 86.66666666666667
# Eigenpixel= 82       percentuale classificazione= 86.66666666666667
# Eigenpixel= 83       percentuale classificazione= 86.66666666666667
# Eigenpixel= 84       percentuale classificazione= 86.66666666666667
# Eigenpixel= 85       percentuale classificazione= 86.66666666666667
# Eigenpixel= 86       percentuale classificazione= 86.66666666666667
# Eigenpixel= 87       percentuale classificazione= 86.66666666666667
# Eigenpixel= 88       percentuale classificazione= 86.66666666666667
# Eigenpixel= 89       percentuale classificazione= 86.66666666666667
# Eigenpixel= 90       percentuale classificazione= 86.66666666666667
# Eigenpixel= 91       percentuale classificazione= 86.66666666666667
# Eigenpixel= 92       percentuale classificazione= 86.66666666666667
# Eigenpixel= 93       percentuale classificazione= 86.66666666666667
# Eigenpixel= 94       percentuale classificazione= 86.66666666666667
# Eigenpixel= 95       percentuale classificazione= 86.66666666666667
# Eigenpixel= 96       percentuale classificazione= 86.66666666666667
# Eigenpixel= 97       percentuale classificazione= 86.66666666666667
# Eigenpixel= 98       percentuale classificazione= 86.66666666666667
# Eigenpixel= 99       percentuale classificazione= 86.66666666666667
# Eigenpixel= 100       percentuale classificazione= 86.66666666666667
# Eigenpixel= 101       percentuale classificazione= 86.66666666666667
# Eigenpixel= 102       percentuale classificazione= 86.66666666666667
# Eigenpixel= 103       percentuale classificazione= 86.66666666666667
# Eigenpixel= 104       percentuale classificazione= 86.66666666666667
# Eigenpixel= 105       percentuale classificazione= 87.5
# Eigenpixel= 106       percentuale classificazione= 87.5
# Eigenpixel= 107       percentuale classificazione= 87.5
# Eigenpixel= 108       percentuale classificazione= 87.5
# Eigenpixel= 109       percentuale classificazione= 86.66666666666667
# Eigenpixel= 110       percentuale classificazione= 86.66666666666667
# Eigenpixel= 111       percentuale classificazione= 86.66666666666667
# Eigenpixel= 112       percentuale classificazione= 86.66666666666667
# Eigenpixel= 113       percentuale classificazione= 87.5
# Eigenpixel= 114       percentuale classificazione= 86.66666666666667
# Eigenpixel= 115       percentuale classificazione= 86.66666666666667
# Eigenpixel= 116       percentuale classificazione= 87.5
# Eigenpixel= 117       percentuale classificazione= 86.66666666666667
# Eigenpixel= 118       percentuale classificazione= 87.5
# Eigenpixel= 119       percentuale classificazione= 87.5
# Eigenpixel= 120       percentuale classificazione= 87.5
# Eigenpixel= 121       percentuale classificazione= 87.5
# Eigenpixel= 122       percentuale classificazione= 86.66666666666667
# Eigenpixel= 123       percentuale classificazione= 86.66666666666667
# Eigenpixel= 124       percentuale classificazione= 86.66666666666667
# Eigenpixel= 125       percentuale classificazione= 86.66666666666667
# Eigenpixel= 126       percentuale classificazione= 86.66666666666667
# Eigenpixel= 127       percentuale classificazione= 86.66666666666667
# Eigenpixel= 128       percentuale classificazione= 86.66666666666667
# Eigenpixel= 129       percentuale classificazione= 86.66666666666667
# Eigenpixel= 130       percentuale classificazione= 86.66666666666667
# Eigenpixel= 131       percentuale classificazione= 87.5
# Eigenpixel= 132       percentuale classificazione= 86.66666666666667
# Eigenpixel= 133       percentuale classificazione= 86.66666666666667
# Eigenpixel= 134       percentuale classificazione= 86.66666666666667
# Eigenpixel= 135       percentuale classificazione= 86.66666666666667
# Eigenpixel= 136       percentuale classificazione= 86.66666666666667
# Eigenpixel= 137       percentuale classificazione= 86.66666666666667
# Eigenpixel= 138       percentuale classificazione= 86.66666666666667
# Eigenpixel= 139       percentuale classificazione= 86.66666666666667
# Eigenpixel= 140       percentuale classificazione= 86.66666666666667
# Eigenpixel= 141       percentuale classificazione= 86.66666666666667
# Eigenpixel= 142       percentuale classificazione= 86.66666666666667
# Eigenpixel= 143       percentuale classificazione= 86.66666666666667
# Eigenpixel= 144       percentuale classificazione= 86.66666666666667
# Eigenpixel= 145       percentuale classificazione= 86.66666666666667
# Eigenpixel= 146       percentuale classificazione= 86.66666666666667
# Eigenpixel= 147       percentuale classificazione= 86.66666666666667
# Eigenpixel= 148       percentuale classificazione= 86.66666666666667
# Eigenpixel= 149       percentuale classificazione= 86.66666666666667
# Eigenpixel= 150       percentuale classificazione= 86.66666666666667
# Eigenpixel= 151       percentuale classificazione= 86.66666666666667
# Eigenpixel= 152       percentuale classificazione= 86.66666666666667
# Eigenpixel= 153       percentuale classificazione= 86.66666666666667
# Eigenpixel= 154       percentuale classificazione= 86.66666666666667
# Eigenpixel= 155       percentuale classificazione= 86.66666666666667
# Eigenpixel= 156       percentuale classificazione= 86.66666666666667
# Eigenpixel= 157       percentuale classificazione= 86.66666666666667
# Eigenpixel= 158       percentuale classificazione= 86.66666666666667
# Eigenpixel= 159       percentuale classificazione= 86.66666666666667
# Eigenpixel= 160       percentuale classificazione= 86.66666666666667
# Eigenpixel= 161       percentuale classificazione= 86.66666666666667
# Eigenpixel= 162       percentuale classificazione= 86.66666666666667
# Eigenpixel= 163       percentuale classificazione= 86.66666666666667
# Eigenpixel= 164       percentuale classificazione= 86.66666666666667
# Eigenpixel= 165       percentuale classificazione= 86.66666666666667
# Eigenpixel= 166       percentuale classificazione= 87.5
# Eigenpixel= 167       percentuale classificazione= 87.5
# Eigenpixel= 168       percentuale classificazione= 87.5
# Eigenpixel= 169       percentuale classificazione= 87.5
# Eigenpixel= 170       percentuale classificazione= 87.5
# Eigenpixel= 171       percentuale classificazione= 87.5
# Eigenpixel= 172       percentuale classificazione= 87.5
# Eigenpixel= 173       percentuale classificazione= 86.66666666666667
# Eigenpixel= 174       percentuale classificazione= 86.66666666666667
# Eigenpixel= 175       percentuale classificazione= 87.5
# Eigenpixel= 176       percentuale classificazione= 87.5
# Eigenpixel= 177       percentuale classificazione= 87.5
# Eigenpixel= 178       percentuale classificazione= 87.5
# Eigenpixel= 179       percentuale classificazione= 87.5
# Eigenpixel= 180       percentuale classificazione= 87.5
# Eigenpixel= 181       percentuale classificazione= 87.5
# Eigenpixel= 182       percentuale classificazione= 88.33333333333333
# Eigenpixel= 183       percentuale classificazione= 88.33333333333333
# Eigenpixel= 184       percentuale classificazione= 88.33333333333333
# Eigenpixel= 185       percentuale classificazione= 88.33333333333333
# Eigenpixel= 186       percentuale classificazione= 88.33333333333333
# Eigenpixel= 187       percentuale classificazione= 88.33333333333333
# Eigenpixel= 188       percentuale classificazione= 88.33333333333333
# Eigenpixel= 189       percentuale classificazione= 88.33333333333333
# Eigenpixel= 190       percentuale classificazione= 88.33333333333333
# Eigenpixel= 191       percentuale classificazione= 88.33333333333333
# Eigenpixel= 192       percentuale classificazione= 88.33333333333333
# Eigenpixel= 193       percentuale classificazione= 87.5
# Eigenpixel= 194       percentuale classificazione= 88.33333333333333
# Eigenpixel= 195       percentuale classificazione= 88.33333333333333
# Eigenpixel= 196       percentuale classificazione= 88.33333333333333
# Eigenpixel= 197       percentuale classificazione= 88.33333333333333
# Eigenpixel= 198       percentuale classificazione= 87.5
# Eigenpixel= 199       percentuale classificazione= 87.5
# Eigenpixel= 200       percentuale classificazione= 87.5
# Eigenpixel= 201       percentuale classificazione= 87.5
# Eigenpixel= 202       percentuale classificazione= 87.5
# Eigenpixel= 203       percentuale classificazione= 87.5
# Eigenpixel= 204       percentuale classificazione= 87.5
# Eigenpixel= 205       percentuale classificazione= 87.5
# Eigenpixel= 206       percentuale classificazione= 87.5
# Eigenpixel= 207       percentuale classificazione= 87.5
# Eigenpixel= 208       percentuale classificazione= 86.66666666666667
# Eigenpixel= 209       percentuale classificazione= 86.66666666666667
# Eigenpixel= 210       percentuale classificazione= 86.66666666666667
# Eigenpixel= 211       percentuale classificazione= 86.66666666666667
# Eigenpixel= 212       percentuale classificazione= 86.66666666666667
# Eigenpixel= 213       percentuale classificazione= 86.66666666666667
# Eigenpixel= 214       percentuale classificazione= 86.66666666666667
# Eigenpixel= 215       percentuale classificazione= 86.66666666666667
# Eigenpixel= 216       percentuale classificazione= 86.66666666666667
# Eigenpixel= 217       percentuale classificazione= 86.66666666666667
# Eigenpixel= 218       percentuale classificazione= 86.66666666666667
# Eigenpixel= 219       percentuale classificazione= 86.66666666666667
# Eigenpixel= 220       percentuale classificazione= 86.66666666666667
# Eigenpixel= 221       percentuale classificazione= 86.66666666666667
# Eigenpixel= 222       percentuale classificazione= 86.66666666666667
# Eigenpixel= 223       percentuale classificazione= 86.66666666666667
# Eigenpixel= 224       percentuale classificazione= 86.66666666666667
# Eigenpixel= 225       percentuale classificazione= 86.66666666666667
# Eigenpixel= 226       percentuale classificazione= 86.66666666666667
# Eigenpixel= 227       percentuale classificazione= 86.66666666666667
# Eigenpixel= 228       percentuale classificazione= 86.66666666666667
# Eigenpixel= 229       percentuale classificazione= 86.66666666666667
# Eigenpixel= 230       percentuale classificazione= 86.66666666666667
# Eigenpixel= 231       percentuale classificazione= 86.66666666666667
# Eigenpixel= 232       percentuale classificazione= 86.66666666666667
# Eigenpixel= 233       percentuale classificazione= 86.66666666666667
# Eigenpixel= 234       percentuale classificazione= 86.66666666666667
# Eigenpixel= 235       percentuale classificazione= 86.66666666666667
# Eigenpixel= 236       percentuale classificazione= 86.66666666666667
# Eigenpixel= 237       percentuale classificazione= 86.66666666666667
# Eigenpixel= 238       percentuale classificazione= 86.66666666666667
# Eigenpixel= 239       percentuale classificazione= 86.66666666666667
# Eigenpixel= 240       percentuale classificazione= 86.66666666666667
# Eigenpixel= 241       percentuale classificazione= 86.66666666666667
# Eigenpixel= 242       percentuale classificazione= 86.66666666666667
# Eigenpixel= 243       percentuale classificazione= 86.66666666666667
# Eigenpixel= 244       percentuale classificazione= 86.66666666666667
# Eigenpixel= 245       percentuale classificazione= 86.66666666666667
# Eigenpixel= 246       percentuale classificazione= 86.66666666666667
# Eigenpixel= 247       percentuale classificazione= 87.5
# Eigenpixel= 248       percentuale classificazione= 87.5
# Eigenpixel= 249       percentuale classificazione= 86.66666666666667
# Eigenpixel= 250       percentuale classificazione= 86.66666666666667
# Eigenpixel= 251       percentuale classificazione= 86.66666666666667
# Eigenpixel= 252       percentuale classificazione= 86.66666666666667
# Eigenpixel= 253       percentuale classificazione= 86.66666666666667
# Eigenpixel= 254       percentuale classificazione= 87.5
# Eigenpixel= 255       percentuale classificazione= 88.33333333333333
# Eigenpixel= 256       percentuale classificazione= 88.33333333333333
# Eigenpixel= 257       percentuale classificazione= 88.33333333333333
# Eigenpixel= 258       percentuale classificazione= 88.33333333333333
# Eigenpixel= 259       percentuale classificazione= 88.33333333333333
# Eigenpixel= 260       percentuale classificazione= 88.33333333333333
# Eigenpixel= 261       percentuale classificazione= 88.33333333333333
# Eigenpixel= 262       percentuale classificazione= 88.33333333333333
# Eigenpixel= 263       percentuale classificazione= 88.33333333333333
# Eigenpixel= 264       percentuale classificazione= 88.33333333333333
# Eigenpixel= 265       percentuale classificazione= 88.33333333333333
# Eigenpixel= 266       percentuale classificazione= 88.33333333333333
# Eigenpixel= 267       percentuale classificazione= 88.33333333333333
# Eigenpixel= 268       percentuale classificazione= 88.33333333333333
# Eigenpixel= 269       percentuale classificazione= 88.33333333333333
# Eigenpixel= 270       percentuale classificazione= 88.33333333333333
# Eigenpixel= 271       percentuale classificazione= 88.33333333333333
# Eigenpixel= 272       percentuale classificazione= 88.33333333333333
# Eigenpixel= 273       percentuale classificazione= 88.33333333333333
# Eigenpixel= 274       percentuale classificazione= 88.33333333333333
# Eigenpixel= 275       percentuale classificazione= 88.33333333333333
# Eigenpixel= 276       percentuale classificazione= 88.33333333333333
# Eigenpixel= 277       percentuale classificazione= 88.33333333333333
# Eigenpixel= 278       percentuale classificazione= 88.33333333333333
# Eigenpixel= 279       percentuale classificazione= 88.33333333333333
# Eigenpixel= 280       percentuale classificazione= 88.33333333333333
