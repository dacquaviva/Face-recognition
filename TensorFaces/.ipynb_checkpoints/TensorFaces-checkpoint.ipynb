# %%
# !pip install tensorly
# Out:
# Requirement already satisfied: tensorly in /home/daniele/anaconda3/lib/python3.6/site-packages (0.4.2)
# Requirement already satisfied: nose in /home/daniele/anaconda3/lib/python3.6/site-packages (from tensorly) (1.3.7)
# Requirement already satisfied: scipy in /home/daniele/anaconda3/lib/python3.6/site-packages (from tensorly) (1.1.0)
# Requirement already satisfied: numpy in /home/daniele/anaconda3/lib/python3.6/site-packages (from tensorly) (1.15.2)

# %%
import tensorly 
import numpy as np
from PIL import Image
import matplotlib.pylab as plt
from numpy import linalg as la
# Out:
# Using numpy backend.

# %% [markdown]
# # Tensore di immagini di trainig

# %%
tensor_immagini_traning = np.zeros((10304,7,40)) #array con tutte le immagini (7 trainig
for i in range(40):
    for j in range(7):
        tensor_immagini_traning[:,j,i] = np.reshape(plt.imread(("../Data-set/"+"s"+str(i+1)+'/'+str(j+1)+'.pgm')), (10304))

# %%
plt.imshow(np.reshape(tensor_immagini_traning[:,0,0],(112,92)), cmap='gray')

# %% [markdown]
# # HOSVD (calcolo svd sui vari unfolding)

# %%
U1, s1, V1 = np.linalg.svd(tensorly.unfold(tensor_immagini_traning,0),full_matrices =False)
U2, s2, V2 = np.linalg.svd(tensorly.unfold(tensor_immagini_traning,1),full_matrices=False)
U3, s3, V3 = np.linalg.svd(tensorly.unfold(tensor_immagini_traning,2),full_matrices=False)

# %%
U1.shape
# Out:
# (10304, 280)

# %%
fig1 = plt.figure(figsize=(6,4))
sing_vals = np.arange(280) + 1
plt.plot(sing_vals, s1, 'ro-', linewidth=2)
plt.title('Plot delle variaze')
plt.xlabel('Principal Component')
plt.ylabel('Singular values')
# Out:
# Text(0,0.5,'Singular values')

# %%
fig1 = plt.figure(figsize=(6,4))
sing_vals = np.arange(7) + 1
plt.plot(sing_vals, s2, 'ro-', linewidth=2)
plt.title('Plot delle variaze')
plt.xlabel('Principal Component')
plt.ylabel('Singular values')
# Out:
# Text(0,0.5,'Singular values')

# %%
n_p = 5

# %%
p = n_p * n_p

# %%
q = 3 #(massimo 7)

# %% [markdown]
# ## considero solo p eigenpixel e q eigenpeople   p>q

# %%
U_p = np.zeros((10304,p))
for i in range (p):
    U_p[:,i] = U1[:,i]

# %%
U_q = np.zeros((7,q))
for i in range (q):
    U_q[:,i] = U2[:,i]

# %%
fig = plt.figure(figsize=(15,15))
for i in range (p):
    plt.subplot(n_p,5,i+1)
    plt.imshow(np.reshape(U_p[:,i],(112,92)), cmap='gray')

# %% [markdown]
# # Calcolo core tensor

# %%
S=tensorly.tenalg.mode_dot(tensor_immagini_traning, np.transpose(U_p), mode=0)
S=tensorly.tenalg.mode_dot(S, np.transpose(U_q), mode=1)
#S=tensorly.tenalg.mode_dot(S, np.transpose(U3), mode=2)

# %%
S.shape
# Out:
# (25, 3, 40)

# %% [markdown]
# # Provo a classificare una sola immagine di test

# %%
immagine_test = np.reshape(plt.imread(("../Data-set/s40/10.pgm")), (1,10304))

# %% [markdown]
# # Proietto l'immagine di test lungo gli U_p

# %%
immagine_test_tens = U_p.T.dot(immagine_test.T)

# %%
v = np.reshape(immagine_test_tens,((n_p,n_p)))

# %%
plt.imshow(v, cmap='gray')

# %% [markdown]
# ## calcolo basi per ogni persona(svd di ogni slice frontale) considerando solo il primo autovettore di sinistra, successivamente classifico l'immagine

# %%
k = 2
B_u = np.zeros((p,k,40))
for i in range (40):
    U1, s1, V1 = np.linalg.svd(S[:,:,i],full_matrices =False)
    for j in range(k):
        B_u[:,j,i] = U1[:,j]

# %%
core_basis_residui = np.zeros((40))
for i in range (40):
    x_u = B_u[:,:,i].T.dot(immagine_test_tens) 
    core_basis_residui[i] =  np.linalg.norm(immagine_test_tens - B_u[:,:,i].dot(x_u), 2)

# %%
core_basis_residui.argmin()
# Out:
# 39

# %% [markdown]
# # Ripeto l'esperimento considerando tutte le immagini di test

# %% [markdown]
# #

# %% [markdown]
# ## calcolo le basi per ogni persona

# %%
k = 2
B_u = np.zeros((p,k,40))
for i in range (40):
    U1, s1, V1 = np.linalg.svd(S[:,:,i],full_matrices =False)
    for j in range(k):
        B_u[:,j,i] =  U1[:,j]

# %% [markdown]
# ## Tensore di immagine di test(non vengono applicate operazioni tensoriali su tale tensore), le immagini vengono considerate come vettori per la classificazione

# %%
tensor_immagini_test = np.zeros((10304,3,40)) #tensore con 3 immagini di test per ogni persona(40 persone)
for i in range(40):
    for j in range(3):
        tensor_immagini_test[:,j,i] = np.reshape(plt.imread(("../Data-set/"+"s"+str(i+1)+'/'+str(j+8)+'.pgm')), (10304))

# %% [markdown]
# ## proietto ogni singola immagine lungo gli eigenpixel

# %%
tensor_immagini_testj=tensorly.tenalg.mode_dot(tensor_immagini_test, np.transpose(U_p), mode=0)#proietto d*Uj

# %% [markdown]
# # Classifico ogni singola immagine di test

# %%
residui = np.zeros(40)
residui_minimi = np.zeros((40,3))
for i in range(40):#persone
    for j in range(3):#immagini stessa persona classificate una alla volta
        for k in range(40):
            x_u = B_u[:,:,k].T.dot(tensor_immagini_testj[:,j,i]) 
            residui[k] =  np.linalg.norm(tensor_immagini_testj[:,j,i] - B_u[:,:,k].dot(x_u) , 2)
        residui_minimi[i,j] = residui.argmin()

# %%
residui_minimi
# Out:
# array([[ 0.,  0., 12.],
#        [ 1.,  1.,  1.],
#        [ 2.,  2.,  2.],
#        [ 3.,  3.,  3.],
#        [39., 39., 39.],
#        [ 5.,  5.,  5.],
#        [ 6.,  6.,  6.],
#        [ 7.,  7.,  7.],
#        [ 8.,  8.,  8.],
#        [ 9.,  9., 37.],
#        [10., 10., 10.],
#        [11., 11., 11.],
#        [12., 12., 12.],
#        [13., 13., 13.],
#        [14., 14., 14.],
#        [ 0., 15., 15.],
#        [16., 16., 16.],
#        [17., 17., 39.],
#        [18., 10., 18.],
#        [19., 19., 19.],
#        [20., 20., 20.],
#        [21., 21., 21.],
#        [22., 22., 37.],
#        [23., 23., 23.],
#        [24., 24., 24.],
#        [25., 25., 25.],
#        [26., 26., 26.],
#        [36., 27., 27.],
#        [28., 28., 28.],
#        [29., 29., 29.],
#        [30., 30., 30.],
#        [31., 31., 31.],
#        [32., 32., 32.],
#        [33., 33., 33.],
#        [34.,  0., 39.],
#        [35., 35., 35.],
#        [36., 36., 36.],
#        [37., 37., 37.],
#        [38., 38., 38.],
#        [39., 39., 39.]])

# %%
num_classificazioni_corrette = 0
k = 0
for i in range(40):
    for j in range(3):
        if(residui_minimi[i,j]==k):
            num_classificazioni_corrette = num_classificazioni_corrette + 1
    k =k + 1

# %%
(num_classificazioni_corrette/120)*100
# Out:
# 90.0

# %% [markdown]
# # Ripeto l'esperimento iterando(considerando) su tutti gli eigenpixel in maniera incrementale

# %%
def hosvd_classificazione(U_p,p,k,U_q,tensor_immagini_traning,tensor_immagini_test):
    S=tensorly.tenalg.mode_dot(tensor_immagini_traning, np.transpose(U_p), mode=0)
    S=tensorly.tenalg.mode_dot(S, np.transpose(U_q), mode=1)
    #S=tensorly.tenalg.mode_dot(S, np.transpose(U3), mode=2)
    B_u = np.zeros((p,k,40))#calcoliamo basi una per ognuna delle 40 persone(prendiamo solo il primo vettore singolare sinistro della svd sulle slice frontali dove ogni slice rappresenta una persona)
    for i in range (40):
        U1, s1, V1 = np.linalg.svd(S[:,:,i],full_matrices =False)
        for j in range(k):
            B_u[:,j,i] =  U1[:,j]
    tensor_immagini_testj=tensorly.tenalg.mode_dot(tensor_immagini_test, np.transpose(U_p), mode=0)#proietto d*Uj
    residui = np.zeros(40)
    residui_minimi = np.zeros((40,3))
    for i in range(40):#persone
        for j in range(3):#immagini stessa persona classificate una alla volta
            for k in range(40):
                x_u = B_u[:,:,k].T.dot(tensor_immagini_testj[:,j,i]) 
                residui[k] =  np.linalg.norm(tensor_immagini_testj[:,j,i] - B_u[:,:,k].dot(x_u) , 2)
            residui_minimi[i,j] = residui.argmin()
    num_classificazioni_corrette = 0
    k = 0
    for i in range(40):
        for j in range(3):
            if(residui_minimi[i,j]==k):
                num_classificazioni_corrette = num_classificazioni_corrette + 1
        k =k + 1
    return (num_classificazioni_corrette/120)*100

# %%
tensor_immagini_traning = np.zeros((10304,7,40)) #array con tutte le immagini (7 trainig, 3 test)
for i in range(40):
    for j in range(7):
        tensor_immagini_traning[:,j,i] = np.reshape(plt.imread(("../Data-set/"+"s"+str(i+1)+'/'+str(j+1)+'.pgm')), (10304))

# %%
U1, s1, V1 = np.linalg.svd(tensorly.unfold(tensor_immagini_traning,0),full_matrices =False)
U2, s2, V2 = np.linalg.svd(tensorly.unfold(tensor_immagini_traning,1),full_matrices=False)
U3, s3, V3 = np.linalg.svd(tensorly.unfold(tensor_immagini_traning,2),full_matrices=False)

# %%
q = 2 #(massimo 7)
U_q = np.zeros((7,q))
for i in range (q):
    U_q[:,i] = U2[:,i]

# %%
tensor_immagini_test = np.zeros((10304,3,40)) #tensore con 3 immagini di test per ogni persona(40 persone)
for i in range(40):
    for j in range(3):
        tensor_immagini_test[:,j,i] = np.reshape(plt.imread(("../Data-set/"+"s"+str(i+1)+'/'+str(j+8)+'.pgm')), (10304))

# %%
percentuale_classificazione = np.zeros((280))
for p in range(2,281):
    U_p = np.zeros((10304,p))
    for j in range (p):
        U_p[:,j] = U1[:,j]
    percentuale_classificazione[p-1] = hosvd_classificazione(U_p,p,2,U_q,tensor_immagini_traning,tensor_immagini_test)
    print("Eigenpixel= "+ str(p)+ "       percentuale classificazione= " + str(percentuale_classificazione[p-1]))
# Out:
# Eigenpixel= 2       percentuale classificazione= 2.5
# Eigenpixel= 3       percentuale classificazione= 7.5
# Eigenpixel= 4       percentuale classificazione= 29.166666666666668
# Eigenpixel= 5       percentuale classificazione= 46.666666666666664
# Eigenpixel= 6       percentuale classificazione= 63.33333333333333
# Eigenpixel= 7       percentuale classificazione= 75.83333333333333
# Eigenpixel= 8       percentuale classificazione= 79.16666666666666
# Eigenpixel= 9       percentuale classificazione= 80.83333333333333
# Eigenpixel= 10       percentuale classificazione= 84.16666666666667
# Eigenpixel= 11       percentuale classificazione= 84.16666666666667
# Eigenpixel= 12       percentuale classificazione= 85.83333333333333
# Eigenpixel= 13       percentuale classificazione= 85.0
# Eigenpixel= 14       percentuale classificazione= 86.66666666666667
# Eigenpixel= 15       percentuale classificazione= 87.5
# Eigenpixel= 16       percentuale classificazione= 88.33333333333333
# Eigenpixel= 17       percentuale classificazione= 87.5
# Eigenpixel= 18       percentuale classificazione= 89.16666666666667
# Eigenpixel= 19       percentuale classificazione= 89.16666666666667
# Eigenpixel= 20       percentuale classificazione= 90.83333333333333
# Eigenpixel= 21       percentuale classificazione= 91.66666666666666
# Eigenpixel= 22       percentuale classificazione= 90.83333333333333
# Eigenpixel= 23       percentuale classificazione= 90.0
# Eigenpixel= 24       percentuale classificazione= 90.0
# Eigenpixel= 25       percentuale classificazione= 90.0
# Eigenpixel= 26       percentuale classificazione= 90.83333333333333
# Eigenpixel= 27       percentuale classificazione= 90.83333333333333
# Eigenpixel= 28       percentuale classificazione= 90.0
# Eigenpixel= 29       percentuale classificazione= 90.0
# Eigenpixel= 30       percentuale classificazione= 90.0
# Eigenpixel= 31       percentuale classificazione= 90.0
# Eigenpixel= 32       percentuale classificazione= 90.0
# Eigenpixel= 33       percentuale classificazione= 90.83333333333333
# Eigenpixel= 34       percentuale classificazione= 90.83333333333333
# Eigenpixel= 35       percentuale classificazione= 90.83333333333333
# Eigenpixel= 36       percentuale classificazione= 91.66666666666666
# Eigenpixel= 37       percentuale classificazione= 92.5
# Eigenpixel= 38       percentuale classificazione= 92.5
# Eigenpixel= 39       percentuale classificazione= 91.66666666666666
# Eigenpixel= 40       percentuale classificazione= 91.66666666666666
# Eigenpixel= 41       percentuale classificazione= 91.66666666666666
# Eigenpixel= 42       percentuale classificazione= 91.66666666666666
# Eigenpixel= 43       percentuale classificazione= 91.66666666666666
# Eigenpixel= 44       percentuale classificazione= 91.66666666666666
# Eigenpixel= 45       percentuale classificazione= 91.66666666666666
# Eigenpixel= 46       percentuale classificazione= 91.66666666666666
# Eigenpixel= 47       percentuale classificazione= 91.66666666666666
# Eigenpixel= 48       percentuale classificazione= 91.66666666666666
# Eigenpixel= 49       percentuale classificazione= 92.5
# Eigenpixel= 50       percentuale classificazione= 92.5
# Eigenpixel= 51       percentuale classificazione= 92.5
# Eigenpixel= 52       percentuale classificazione= 92.5
# Eigenpixel= 53       percentuale classificazione= 92.5
# Eigenpixel= 54       percentuale classificazione= 92.5
# Eigenpixel= 55       percentuale classificazione= 92.5
# Eigenpixel= 56       percentuale classificazione= 92.5
# Eigenpixel= 57       percentuale classificazione= 92.5
# Eigenpixel= 58       percentuale classificazione= 92.5
# Eigenpixel= 59       percentuale classificazione= 92.5
# Eigenpixel= 60       percentuale classificazione= 92.5
# Eigenpixel= 61       percentuale classificazione= 92.5
# Eigenpixel= 62       percentuale classificazione= 92.5
# Eigenpixel= 63       percentuale classificazione= 92.5
# Eigenpixel= 64       percentuale classificazione= 92.5
# Eigenpixel= 65       percentuale classificazione= 92.5
# Eigenpixel= 66       percentuale classificazione= 92.5
# Eigenpixel= 67       percentuale classificazione= 92.5
# Eigenpixel= 68       percentuale classificazione= 92.5
# Eigenpixel= 69       percentuale classificazione= 92.5
# Eigenpixel= 70       percentuale classificazione= 92.5
# Eigenpixel= 71       percentuale classificazione= 92.5
# Eigenpixel= 72       percentuale classificazione= 92.5
# Eigenpixel= 73       percentuale classificazione= 92.5
# Eigenpixel= 74       percentuale classificazione= 92.5
# Eigenpixel= 75       percentuale classificazione= 92.5
# Eigenpixel= 76       percentuale classificazione= 92.5
# Eigenpixel= 77       percentuale classificazione= 92.5
# Eigenpixel= 78       percentuale classificazione= 92.5
# Eigenpixel= 79       percentuale classificazione= 92.5
# Eigenpixel= 80       percentuale classificazione= 92.5
# Eigenpixel= 81       percentuale classificazione= 92.5
# Eigenpixel= 82       percentuale classificazione= 92.5
# Eigenpixel= 83       percentuale classificazione= 92.5
# Eigenpixel= 84       percentuale classificazione= 92.5
# Eigenpixel= 85       percentuale classificazione= 92.5
# Eigenpixel= 86       percentuale classificazione= 92.5
# Eigenpixel= 87       percentuale classificazione= 92.5
# Eigenpixel= 88       percentuale classificazione= 92.5
# Eigenpixel= 89       percentuale classificazione= 92.5
# Eigenpixel= 90       percentuale classificazione= 92.5
# Eigenpixel= 91       percentuale classificazione= 92.5
# Eigenpixel= 92       percentuale classificazione= 92.5
# Eigenpixel= 93       percentuale classificazione= 92.5
# Eigenpixel= 94       percentuale classificazione= 92.5
# Eigenpixel= 95       percentuale classificazione= 92.5
# Eigenpixel= 96       percentuale classificazione= 92.5
# Eigenpixel= 97       percentuale classificazione= 92.5
# Eigenpixel= 98       percentuale classificazione= 92.5
# Eigenpixel= 99       percentuale classificazione= 92.5
# Eigenpixel= 100       percentuale classificazione= 92.5
# Eigenpixel= 101       percentuale classificazione= 92.5
# Eigenpixel= 102       percentuale classificazione= 92.5
# Eigenpixel= 103       percentuale classificazione= 92.5
# Eigenpixel= 104       percentuale classificazione= 92.5
# Eigenpixel= 105       percentuale classificazione= 92.5
# Eigenpixel= 106       percentuale classificazione= 92.5
# Eigenpixel= 107       percentuale classificazione= 92.5
# Eigenpixel= 108       percentuale classificazione= 92.5
# Eigenpixel= 109       percentuale classificazione= 92.5
# Eigenpixel= 110       percentuale classificazione= 92.5
# Eigenpixel= 111       percentuale classificazione= 92.5
# Eigenpixel= 112       percentuale classificazione= 92.5
# Eigenpixel= 113       percentuale classificazione= 92.5
# Eigenpixel= 114       percentuale classificazione= 92.5
# Eigenpixel= 115       percentuale classificazione= 92.5
# Eigenpixel= 116       percentuale classificazione= 92.5
# Eigenpixel= 117       percentuale classificazione= 92.5
# Eigenpixel= 118       percentuale classificazione= 92.5
# Eigenpixel= 119       percentuale classificazione= 92.5
# Eigenpixel= 120       percentuale classificazione= 92.5
# Eigenpixel= 121       percentuale classificazione= 92.5
# Eigenpixel= 122       percentuale classificazione= 92.5
# Eigenpixel= 123       percentuale classificazione= 92.5
# Eigenpixel= 124       percentuale classificazione= 92.5
# Eigenpixel= 125       percentuale classificazione= 92.5
# Eigenpixel= 126       percentuale classificazione= 92.5
# Eigenpixel= 127       percentuale classificazione= 92.5
# Eigenpixel= 128       percentuale classificazione= 92.5
# Eigenpixel= 129       percentuale classificazione= 92.5
# Eigenpixel= 130       percentuale classificazione= 92.5
# Eigenpixel= 131       percentuale classificazione= 92.5
# Eigenpixel= 132       percentuale classificazione= 92.5
# Eigenpixel= 133       percentuale classificazione= 92.5
# Eigenpixel= 134       percentuale classificazione= 92.5
# Eigenpixel= 135       percentuale classificazione= 92.5
# Eigenpixel= 136       percentuale classificazione= 92.5
# Eigenpixel= 137       percentuale classificazione= 92.5
# Eigenpixel= 138       percentuale classificazione= 92.5
# Eigenpixel= 139       percentuale classificazione= 92.5
# Eigenpixel= 140       percentuale classificazione= 92.5
# Eigenpixel= 141       percentuale classificazione= 92.5
# Eigenpixel= 142       percentuale classificazione= 92.5
# Eigenpixel= 143       percentuale classificazione= 92.5
# Eigenpixel= 144       percentuale classificazione= 92.5
# Eigenpixel= 145       percentuale classificazione= 92.5
# Eigenpixel= 146       percentuale classificazione= 92.5
# Eigenpixel= 147       percentuale classificazione= 92.5
# Eigenpixel= 148       percentuale classificazione= 92.5
# Eigenpixel= 149       percentuale classificazione= 92.5
# Eigenpixel= 150       percentuale classificazione= 92.5
# Eigenpixel= 151       percentuale classificazione= 92.5
# Eigenpixel= 152       percentuale classificazione= 92.5
# Eigenpixel= 153       percentuale classificazione= 92.5
# Eigenpixel= 154       percentuale classificazione= 92.5
# Eigenpixel= 155       percentuale classificazione= 92.5
# Eigenpixel= 156       percentuale classificazione= 92.5
# Eigenpixel= 157       percentuale classificazione= 92.5
# Eigenpixel= 158       percentuale classificazione= 92.5
# Eigenpixel= 159       percentuale classificazione= 92.5
# Eigenpixel= 160       percentuale classificazione= 92.5
# Eigenpixel= 161       percentuale classificazione= 92.5
# Eigenpixel= 162       percentuale classificazione= 92.5
# Eigenpixel= 163       percentuale classificazione= 92.5
# Eigenpixel= 164       percentuale classificazione= 92.5
# Eigenpixel= 165       percentuale classificazione= 92.5
# Eigenpixel= 166       percentuale classificazione= 92.5
# Eigenpixel= 167       percentuale classificazione= 92.5
# Eigenpixel= 168       percentuale classificazione= 92.5
# Eigenpixel= 169       percentuale classificazione= 92.5
# Eigenpixel= 170       percentuale classificazione= 92.5
# Eigenpixel= 171       percentuale classificazione= 92.5
# Eigenpixel= 172       percentuale classificazione= 92.5
# Eigenpixel= 173       percentuale classificazione= 92.5
# Eigenpixel= 174       percentuale classificazione= 92.5
# Eigenpixel= 175       percentuale classificazione= 92.5
# Eigenpixel= 176       percentuale classificazione= 92.5
# Eigenpixel= 177       percentuale classificazione= 92.5
# Eigenpixel= 178       percentuale classificazione= 92.5
# Eigenpixel= 179       percentuale classificazione= 92.5
# Eigenpixel= 180       percentuale classificazione= 92.5
# Eigenpixel= 181       percentuale classificazione= 92.5
# Eigenpixel= 182       percentuale classificazione= 92.5
# Eigenpixel= 183       percentuale classificazione= 92.5
# Eigenpixel= 184       percentuale classificazione= 92.5
# Eigenpixel= 185       percentuale classificazione= 92.5
# Eigenpixel= 186       percentuale classificazione= 92.5
# Eigenpixel= 187       percentuale classificazione= 92.5
# Eigenpixel= 188       percentuale classificazione= 92.5
# Eigenpixel= 189       percentuale classificazione= 92.5
# Eigenpixel= 190       percentuale classificazione= 92.5
# Eigenpixel= 191       percentuale classificazione= 92.5
# Eigenpixel= 192       percentuale classificazione= 92.5
# Eigenpixel= 193       percentuale classificazione= 92.5
# Eigenpixel= 194       percentuale classificazione= 92.5
# Eigenpixel= 195       percentuale classificazione= 92.5
# Eigenpixel= 196       percentuale classificazione= 92.5
# Eigenpixel= 197       percentuale classificazione= 92.5
# Eigenpixel= 198       percentuale classificazione= 92.5
# Eigenpixel= 199       percentuale classificazione= 92.5
# Eigenpixel= 200       percentuale classificazione= 92.5
# Eigenpixel= 201       percentuale classificazione= 92.5
# Eigenpixel= 202       percentuale classificazione= 92.5
# Eigenpixel= 203       percentuale classificazione= 92.5
# Eigenpixel= 204       percentuale classificazione= 92.5
# Eigenpixel= 205       percentuale classificazione= 92.5
# Eigenpixel= 206       percentuale classificazione= 92.5
# Eigenpixel= 207       percentuale classificazione= 92.5
# Eigenpixel= 208       percentuale classificazione= 92.5
# Eigenpixel= 209       percentuale classificazione= 92.5
# Eigenpixel= 210       percentuale classificazione= 92.5
# Eigenpixel= 211       percentuale classificazione= 92.5
# Eigenpixel= 212       percentuale classificazione= 92.5
# Eigenpixel= 213       percentuale classificazione= 92.5
# Eigenpixel= 214       percentuale classificazione= 92.5
# Eigenpixel= 215       percentuale classificazione= 92.5
# Eigenpixel= 216       percentuale classificazione= 92.5
# Eigenpixel= 217       percentuale classificazione= 92.5
# Eigenpixel= 218       percentuale classificazione= 92.5
# Eigenpixel= 219       percentuale classificazione= 92.5
# Eigenpixel= 220       percentuale classificazione= 92.5
# Eigenpixel= 221       percentuale classificazione= 92.5
# Eigenpixel= 222       percentuale classificazione= 92.5
# Eigenpixel= 223       percentuale classificazione= 92.5
# Eigenpixel= 224       percentuale classificazione= 92.5
# Eigenpixel= 225       percentuale classificazione= 92.5
# Eigenpixel= 226       percentuale classificazione= 92.5
# Eigenpixel= 227       percentuale classificazione= 92.5
# Eigenpixel= 228       percentuale classificazione= 92.5
# Eigenpixel= 229       percentuale classificazione= 92.5
# Eigenpixel= 230       percentuale classificazione= 92.5
# Eigenpixel= 231       percentuale classificazione= 92.5
# Eigenpixel= 232       percentuale classificazione= 92.5
# Eigenpixel= 233       percentuale classificazione= 92.5
# Eigenpixel= 234       percentuale classificazione= 92.5
# Eigenpixel= 235       percentuale classificazione= 92.5
# Eigenpixel= 236       percentuale classificazione= 92.5
# Eigenpixel= 237       percentuale classificazione= 92.5
# Eigenpixel= 238       percentuale classificazione= 92.5
# Eigenpixel= 239       percentuale classificazione= 92.5
# Eigenpixel= 240       percentuale classificazione= 92.5
# Eigenpixel= 241       percentuale classificazione= 92.5
# Eigenpixel= 242       percentuale classificazione= 92.5
# Eigenpixel= 243       percentuale classificazione= 92.5
# Eigenpixel= 244       percentuale classificazione= 92.5
# Eigenpixel= 245       percentuale classificazione= 92.5
# Eigenpixel= 246       percentuale classificazione= 92.5
# Eigenpixel= 247       percentuale classificazione= 92.5
# Eigenpixel= 248       percentuale classificazione= 92.5
# Eigenpixel= 249       percentuale classificazione= 92.5
# Eigenpixel= 250       percentuale classificazione= 92.5
# Eigenpixel= 251       percentuale classificazione= 92.5
# Eigenpixel= 252       percentuale classificazione= 92.5
# Eigenpixel= 253       percentuale classificazione= 92.5
# Eigenpixel= 254       percentuale classificazione= 92.5
# Eigenpixel= 255       percentuale classificazione= 92.5
# Eigenpixel= 256       percentuale classificazione= 92.5
# Eigenpixel= 257       percentuale classificazione= 92.5
# Eigenpixel= 258       percentuale classificazione= 92.5
# Eigenpixel= 259       percentuale classificazione= 92.5
# Eigenpixel= 260       percentuale classificazione= 92.5
# Eigenpixel= 261       percentuale classificazione= 92.5
# Eigenpixel= 262       percentuale classificazione= 92.5
# Eigenpixel= 263       percentuale classificazione= 92.5
# Eigenpixel= 264       percentuale classificazione= 92.5
# Eigenpixel= 265       percentuale classificazione= 92.5
# Eigenpixel= 266       percentuale classificazione= 92.5
# Eigenpixel= 267       percentuale classificazione= 92.5
# Eigenpixel= 268       percentuale classificazione= 92.5
# Eigenpixel= 269       percentuale classificazione= 92.5
# Eigenpixel= 270       percentuale classificazione= 92.5
# Eigenpixel= 271       percentuale classificazione= 92.5
# Eigenpixel= 272       percentuale classificazione= 92.5
# Eigenpixel= 273       percentuale classificazione= 92.5
# Eigenpixel= 274       percentuale classificazione= 92.5
# Eigenpixel= 275       percentuale classificazione= 92.5
# Eigenpixel= 276       percentuale classificazione= 92.5
# Eigenpixel= 277       percentuale classificazione= 92.5
# Eigenpixel= 278       percentuale classificazione= 92.5
# Eigenpixel= 279       percentuale classificazione= 92.5
# Eigenpixel= 280       percentuale classificazione= 92.5

# %%
fig2 = plt.figure(figsize=(6,4))
eigenpixel_vals = np.arange(280) + 1
plt.plot(eigenpixel_vals, percentuale_classificazione, 'ro-', linewidth=2)
plt.title('Plot classificazione')
plt.xlabel('numero eigenpixel')
plt.ylabel('percentuale classificazione')
# Out:
# Text(0,0.5,'percentuale classificazione')
